# %%
import pandas as pd
import numpy as np
from classify import classify_disease
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from xgboost import XGBClassifier
from imblearn.combine import SMOTEENN
from imblearn.over_sampling import SMOTE
from sklearn.dummy import DummyClassifier
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# <h5 style="color: SkyBlue;">Load Dataset</h5>

# %%
df = pd.read_csv('user_data_for_disease_prediction - unclassified data set.csv')
print(df.head())
# Out:
#    Heart Rate (bpm)  Breathing Rate (brpm)  Oxygen Saturation (%)  \
# 0              80.3                   12.2                   96.4
# 1              73.1                   17.7                   95.9
# 2              72.2                   18.0                   96.0
# 3              70.6                   14.7                   95.1
# 4              99.5                   19.5                   97.6
#
#    Blood Pressure (systolic)  Blood Pressure (diastolic)  Stress Index  \
# 0                      107.3                        74.2          39.6
# 1                       92.4                        70.8          98.7
# 2                      102.4                        75.6          45.3
# 3                      110.0                        62.2          77.8
# 4                      110.2                        73.0          57.3
#
#    Recovery Ability  PNS Index  SNS Index  RMSSD (ms)  SD2 (ms)  \
# 0                 0       -0.9        0.4        49.7      67.9
# 1                 0       -0.6        0.6        34.3      67.4
# 2                 0       -0.9        0.4        40.5      59.0
# 3                 0       -0.6        0.5        35.3      58.2
# 4                 0       -0.2        0.5        37.9      62.3
#
#    Hemoglobin A1c (%)  Mean RRI (ms)  SD1 (ms)  HRV SDNN (ms)  \
# 0                 4.7          958.8      82.3           87.9
# 1                 3.7          853.5      50.9           63.2
# 2                 4.3          873.3      65.4           54.7
# 3                 4.4          693.9      82.6           75.8
# 4                 3.0          826.3      63.9           79.0
#
#    Hemoglobin (g/dl)  Gender (0-M;1-F)
# 0               17.1                 0
# 1               14.7                 1
# 2               13.8                 0
# 3               15.8                 0
# 4               12.5                 1

# %% [markdown]
# <h5 style="color: SkyBlue;">Ranking Disease</h5>

# %%
df["Disease"] = df.apply(classify_disease, axis=1)

disease_counts = df["Disease"].value_counts()

disease_counts_sorted = disease_counts.sort_values(ascending=False)
print(disease_counts_sorted)
# Out:
# Disease
# Atherosclerosis                         152809
# Hypertension                            115644
# Cardiovascular Disease (CVD)             99122
# Chronic Fatigue Syndrome (CFS)           53545
# Respiratory Disease (COPD or Asthma)     28039
# Stress-related Disorders                   352
# Arrhythmias                                284
# Healthy                                     67
# Autonomic Dysfunction                       65
# Diabetes                                    48
# Anaemia                                     25
# Name: count, dtype: int64

# %%
sampled_df_health = df.sample(n=200000, random_state=42)

sampled_disease_counts = sampled_df_health["Disease"].value_counts()

sampled_disease_counts_sorted = sampled_disease_counts.sort_values(ascending=False)
print(sampled_disease_counts_sorted)
# Out:
# Disease
# Atherosclerosis                         67905
# Hypertension                            51521
# Cardiovascular Disease (CVD)            43988
# Chronic Fatigue Syndrome (CFS)          23828
# Respiratory Disease (COPD or Asthma)    12376
# Stress-related Disorders                  155
# Arrhythmias                               136
# Healthy                                    31
# Autonomic Dysfunction                      29
# Diabetes                                   24
# Anaemia                                     7
# Name: count, dtype: int64

# %% [markdown]
# <h5 style="color: SkyBlue;">Synthetic Sampling</h5>

# %%
def apply_smoteenn(sampled_df_health):
    """
    SMOTEENN sampling to balance the dataset.
    
    Parameters:
        sampled_df_health (DataFrame): Data containing features and the target column 'Disease'.
        
    Returns:
        X_balanced (DataFrame): Resampled features.
        y_balanced (Series): Resampled target labels.
        counts (dict): Summary of the balanced dataset.
    """
    # Feature (X) and target (y) separation
    X = sampled_df_health.drop("Disease", axis=1)
    y = sampled_df_health["Disease"]

    smote = SMOTE(k_neighbors=2, random_state=42)
    smote_enn = SMOTEENN(random_state=42, smote=smote)

    # resampling
    X_balanced, y_balanced = smote_enn.fit_resample(X, y)

    counts = {
        "Balanced Feature Shape": X_balanced.shape,
        "Balanced Target Shape": y_balanced.shape,
        "Balanced Distribution": y_balanced.value_counts().to_dict(),
    }
    
    print("Balanced Distribution:")
    for disease, count in counts["Balanced Distribution"].items():
        print(f"{disease}: {count}")

    return X_balanced, y_balanced, counts

X_resampled, y_resampled, counts = apply_smoteenn(sampled_df_health)
# Out:
# Balanced Distribution:
# Anaemia: 67905
# Arrhythmias: 67905
# Autonomic Dysfunction: 67905
# Stress-related Disorders: 67905
# Diabetes: 67905
# Healthy: 67905
# Chronic Fatigue Syndrome (CFS): 66792
# Respiratory Disease (COPD or Asthma): 66781
# Hypertension: 48966
# Cardiovascular Disease (CVD): 38457
# Atherosclerosis: 23506

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_resampled_encoded = le.fit_transform(y_resampled)

# %% [markdown]
# <h5 style="color: SkyBlue;">Helper function batch training</h5>

# %%
def train_and_evaluate(model, X_data, y_data, batch_sizes):
    """
    Trains and evaluates a model over different batch sizes.
    
    Parameters:
        model: sklearn model instance
        X_data: Features for training
        y_data: Target labels
        batch_sizes: List of batch sizes for training
        
    Returns:
        None
    """
    for batch_size in batch_sizes:
        X_batch = X_data.sample(n=min(batch_size, len(X_data)), random_state=42)
        y_batch = y_data.loc[X_batch.index]
        
        model.fit(X_batch, y_batch)
        
        y_pred = model.predict(X_batch)
        print(f"\nBatch Size: {batch_size}")
        print(classification_report(y_batch, y_pred))
        print(f"Accuracy: {accuracy_score(y_batch, y_pred)}\n")

# %% [markdown]
# <h5 style="color: SkyBlue;">Logistic Regression</h5>

# %%
batch_sizes = [200, 400, 800, 1000, 2000, 15000]
logistic_model = LogisticRegression(max_iter=200, random_state=42)
train_and_evaluate(logistic_model, X_resampled, y_resampled, batch_sizes)
# Out:
# c:\Users\zen\Documents\les trucs du boulot\TM R&D\E-Health\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zen\Documents\les trucs du boulot\TM R&D\E-Health\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zen\Documents\les trucs du boulot\TM R&D\E-Health\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Batch Size: 200
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.92      1.00      0.96        23
#                          Arrhythmias       0.89      0.89      0.89        18
#                      Atherosclerosis       0.80      1.00      0.89         4
#                Autonomic Dysfunction       0.67      0.71      0.69        14
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        14
#       Chronic Fatigue Syndrome (CFS)       0.68      0.65      0.67        20
#                             Diabetes       0.71      0.68      0.69        25
#                              Healthy       0.77      0.81      0.79        21
#                         Hypertension       0.83      0.83      0.83        18
# Respiratory Disease (COPD or Asthma)       0.83      0.71      0.77        21
#             Stress-related Disorders       0.59      0.59      0.59        22
#
#                             accuracy                           0.79       200
#                            macro avg       0.79      0.81      0.80       200
#                         weighted avg       0.78      0.79      0.78       200
#
# Accuracy: 0.785
#
#
# Batch Size: 400
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.80      0.84      0.82        44
#                          Arrhythmias       0.76      0.83      0.79        35
#                      Atherosclerosis       0.75      0.75      0.75        12
#                Autonomic Dysfunction       0.63      0.66      0.64        41
#         Cardiovascular Disease (CVD)       0.86      0.82      0.84        22
#       Chronic Fatigue Syndrome (CFS)       0.62      0.63      0.62        38
#                             Diabetes       0.61      0.60      0.61        45
#                              Healthy       0.80      0.73      0.77        45
#                         Hypertension       0.87      0.84      0.86        32
# Respiratory Disease (COPD or Asthma)       0.88      0.77      0.82        39
#             Stress-related Disorders       0.59      0.64      0.61        47
#
#                             accuracy                           0.73       400
#                            macro avg       0.74      0.74      0.74       400
#                         weighted avg       0.73      0.73      0.73       400
#
# Accuracy: 0.7275
#
#
# Batch Size: 800
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.83      0.85      0.84        91
#                          Arrhythmias       0.75      0.85      0.80        82
#                      Atherosclerosis       0.74      0.86      0.79        29
#                Autonomic Dysfunction       0.49      0.45      0.46        74
#         Cardiovascular Disease (CVD)       0.87      0.85      0.86        53
#       Chronic Fatigue Syndrome (CFS)       0.62      0.63      0.62        78
#                             Diabetes       0.58      0.61      0.60        83
#                              Healthy       0.70      0.76      0.73        87
#                         Hypertension       0.94      0.81      0.87        58
# Respiratory Disease (COPD or Asthma)       0.81      0.74      0.77        76
#             Stress-related Disorders       0.62      0.56      0.59        89
#
#                             accuracy                           0.71       800
#                            macro avg       0.72      0.72      0.72       800
#                         weighted avg       0.71      0.71      0.71       800
#
# Accuracy: 0.71125
# c:\Users\zen\Documents\les trucs du boulot\TM R&D\E-Health\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\zen\Documents\les trucs du boulot\TM R&D\E-Health\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Batch Size: 1000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.80      0.84      0.82       110
#                          Arrhythmias       0.78      0.79      0.78       101
#                      Atherosclerosis       0.74      0.74      0.74        35
#                Autonomic Dysfunction       0.50      0.42      0.46        95
#         Cardiovascular Disease (CVD)       0.88      0.86      0.87        71
#       Chronic Fatigue Syndrome (CFS)       0.58      0.64      0.61       101
#                             Diabetes       0.58      0.61      0.59       106
#                              Healthy       0.69      0.77      0.73       105
#                         Hypertension       0.85      0.84      0.84        73
# Respiratory Disease (COPD or Asthma)       0.73      0.63      0.68        98
#             Stress-related Disorders       0.58      0.54      0.56       105
#
#                             accuracy                           0.69      1000
#                            macro avg       0.70      0.70      0.70      1000
#                         weighted avg       0.69      0.69      0.69      1000
#
# Accuracy: 0.69
#
#
# Batch Size: 2000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.81      0.88      0.84       213
#                          Arrhythmias       0.76      0.86      0.81       205
#                      Atherosclerosis       0.73      0.78      0.75        67
#                Autonomic Dysfunction       0.67      0.50      0.57       206
#         Cardiovascular Disease (CVD)       0.86      0.85      0.85       132
#       Chronic Fatigue Syndrome (CFS)       0.59      0.60      0.59       203
#                             Diabetes       0.63      0.55      0.59       190
#                              Healthy       0.67      0.83      0.74       211
#                         Hypertension       0.80      0.73      0.76       153
# Respiratory Disease (COPD or Asthma)       0.73      0.67      0.70       205
#             Stress-related Disorders       0.63      0.63      0.63       215
#
#                             accuracy                           0.71      2000
#                            macro avg       0.72      0.72      0.71      2000
#                         weighted avg       0.71      0.71      0.71      2000
#
# Accuracy: 0.709
# c:\Users\zen\Documents\les trucs du boulot\TM R&D\E-Health\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Batch Size: 15000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.79      0.86      0.82      1547
#                          Arrhythmias       0.71      0.79      0.75      1604
#                      Atherosclerosis       0.74      0.77      0.76       561
#                Autonomic Dysfunction       0.57      0.45      0.51      1582
#         Cardiovascular Disease (CVD)       0.83      0.83      0.83       859
#       Chronic Fatigue Syndrome (CFS)       0.60      0.66      0.63      1519
#                             Diabetes       0.59      0.54      0.57      1551
#                              Healthy       0.66      0.77      0.71      1546
#                         Hypertension       0.78      0.75      0.77      1099
# Respiratory Disease (COPD or Asthma)       0.74      0.62      0.68      1563
#             Stress-related Disorders       0.64      0.64      0.64      1569
#
#                             accuracy                           0.69     15000
#                            macro avg       0.70      0.70      0.70     15000
#                         weighted avg       0.68      0.69      0.68     15000
#
# Accuracy: 0.6870666666666667

# %% [markdown]
# <h5 style="color: SkyBlue;">Decision Tree</h5>

# %%
decision_tree_model = DecisionTreeClassifier(random_state=42)
train_and_evaluate(decision_tree_model, X_resampled, y_resampled, batch_sizes)
# Out:
# Batch Size: 200
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00        23
#                          Arrhythmias       1.00      1.00      1.00        18
#                      Atherosclerosis       1.00      1.00      1.00         4
#                Autonomic Dysfunction       1.00      1.00      1.00        14
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        14
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        20
#                             Diabetes       1.00      1.00      1.00        25
#                              Healthy       1.00      1.00      1.00        21
#                         Hypertension       1.00      1.00      1.00        18
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        21
#             Stress-related Disorders       1.00      1.00      1.00        22
#
#                             accuracy                           1.00       200
#                            macro avg       1.00      1.00      1.00       200
#                         weighted avg       1.00      1.00      1.00       200
#
# Accuracy: 1.0
#
#
# Batch Size: 400
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00        44
#                          Arrhythmias       1.00      1.00      1.00        35
#                      Atherosclerosis       1.00      1.00      1.00        12
#                Autonomic Dysfunction       1.00      1.00      1.00        41
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        22
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        38
#                             Diabetes       1.00      1.00      1.00        45
#                              Healthy       1.00      1.00      1.00        45
#                         Hypertension       1.00      1.00      1.00        32
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        39
#             Stress-related Disorders       1.00      1.00      1.00        47
#
#                             accuracy                           1.00       400
#                            macro avg       1.00      1.00      1.00       400
#                         weighted avg       1.00      1.00      1.00       400
#
# Accuracy: 1.0
#
#
# Batch Size: 800
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00        91
#                          Arrhythmias       1.00      1.00      1.00        82
#                      Atherosclerosis       1.00      1.00      1.00        29
#                Autonomic Dysfunction       1.00      1.00      1.00        74
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        53
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        78
#                             Diabetes       1.00      1.00      1.00        83
#                              Healthy       1.00      1.00      1.00        87
#                         Hypertension       1.00      1.00      1.00        58
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        76
#             Stress-related Disorders       1.00      1.00      1.00        89
#
#                             accuracy                           1.00       800
#                            macro avg       1.00      1.00      1.00       800
#                         weighted avg       1.00      1.00      1.00       800
#
# Accuracy: 1.0
#
#
# Batch Size: 1000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00       110
#                          Arrhythmias       1.00      1.00      1.00       101
#                      Atherosclerosis       1.00      1.00      1.00        35
#                Autonomic Dysfunction       1.00      1.00      1.00        95
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        71
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00       101
#                             Diabetes       1.00      1.00      1.00       106
#                              Healthy       1.00      1.00      1.00       105
#                         Hypertension       1.00      1.00      1.00        73
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        98
#             Stress-related Disorders       1.00      1.00      1.00       105
#
#                             accuracy                           1.00      1000
#                            macro avg       1.00      1.00      1.00      1000
#                         weighted avg       1.00      1.00      1.00      1000
#
# Accuracy: 1.0
#
#
# Batch Size: 2000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00       213
#                          Arrhythmias       1.00      1.00      1.00       205
#                      Atherosclerosis       1.00      1.00      1.00        67
#                Autonomic Dysfunction       1.00      1.00      1.00       206
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00       132
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00       203
#                             Diabetes       1.00      1.00      1.00       190
#                              Healthy       1.00      1.00      1.00       211
#                         Hypertension       1.00      1.00      1.00       153
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00       205
#             Stress-related Disorders       1.00      1.00      1.00       215
#
#                             accuracy                           1.00      2000
#                            macro avg       1.00      1.00      1.00      2000
#                         weighted avg       1.00      1.00      1.00      2000
#
# Accuracy: 1.0
#
#
# Batch Size: 15000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00      1547
#                          Arrhythmias       1.00      1.00      1.00      1604
#                      Atherosclerosis       1.00      1.00      1.00       561
#                Autonomic Dysfunction       1.00      1.00      1.00      1582
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00       859
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00      1519
#                             Diabetes       1.00      1.00      1.00      1551
#                              Healthy       1.00      1.00      1.00      1546
#                         Hypertension       1.00      1.00      1.00      1099
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00      1563
#             Stress-related Disorders       1.00      1.00      1.00      1569
#
#                             accuracy                           1.00     15000
#                            macro avg       1.00      1.00      1.00     15000
#                         weighted avg       1.00      1.00      1.00     15000
#
# Accuracy: 1.0

# %% [markdown]
# <h5 style="color: SkyBlue;">Random Forest</h5>

# %%
random_forest_model = RandomForestClassifier(random_state=42)
train_and_evaluate(random_forest_model, X_resampled, y_resampled, batch_sizes)
# Out:
# Batch Size: 200
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00        23
#                          Arrhythmias       1.00      1.00      1.00        18
#                      Atherosclerosis       1.00      1.00      1.00         4
#                Autonomic Dysfunction       1.00      1.00      1.00        14
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        14
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        20
#                             Diabetes       1.00      1.00      1.00        25
#                              Healthy       1.00      1.00      1.00        21
#                         Hypertension       1.00      1.00      1.00        18
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        21
#             Stress-related Disorders       1.00      1.00      1.00        22
#
#                             accuracy                           1.00       200
#                            macro avg       1.00      1.00      1.00       200
#                         weighted avg       1.00      1.00      1.00       200
#
# Accuracy: 1.0
#
#
# Batch Size: 400
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00        44
#                          Arrhythmias       1.00      1.00      1.00        35
#                      Atherosclerosis       1.00      1.00      1.00        12
#                Autonomic Dysfunction       1.00      1.00      1.00        41
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        22
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        38
#                             Diabetes       1.00      1.00      1.00        45
#                              Healthy       1.00      1.00      1.00        45
#                         Hypertension       1.00      1.00      1.00        32
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        39
#             Stress-related Disorders       1.00      1.00      1.00        47
#
#                             accuracy                           1.00       400
#                            macro avg       1.00      1.00      1.00       400
#                         weighted avg       1.00      1.00      1.00       400
#
# Accuracy: 1.0
#
#
# Batch Size: 800
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00        91
#                          Arrhythmias       1.00      1.00      1.00        82
#                      Atherosclerosis       1.00      1.00      1.00        29
#                Autonomic Dysfunction       1.00      1.00      1.00        74
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        53
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        78
#                             Diabetes       1.00      1.00      1.00        83
#                              Healthy       1.00      1.00      1.00        87
#                         Hypertension       1.00      1.00      1.00        58
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        76
#             Stress-related Disorders       1.00      1.00      1.00        89
#
#                             accuracy                           1.00       800
#                            macro avg       1.00      1.00      1.00       800
#                         weighted avg       1.00      1.00      1.00       800
#
# Accuracy: 1.0
#
#
# Batch Size: 1000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00       110
#                          Arrhythmias       1.00      1.00      1.00       101
#                      Atherosclerosis       1.00      1.00      1.00        35
#                Autonomic Dysfunction       1.00      1.00      1.00        95
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        71
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00       101
#                             Diabetes       1.00      1.00      1.00       106
#                              Healthy       1.00      1.00      1.00       105
#                         Hypertension       1.00      1.00      1.00        73
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        98
#             Stress-related Disorders       1.00      1.00      1.00       105
#
#                             accuracy                           1.00      1000
#                            macro avg       1.00      1.00      1.00      1000
#                         weighted avg       1.00      1.00      1.00      1000
#
# Accuracy: 1.0
#
#
# Batch Size: 2000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00       213
#                          Arrhythmias       1.00      1.00      1.00       205
#                      Atherosclerosis       1.00      1.00      1.00        67
#                Autonomic Dysfunction       1.00      1.00      1.00       206
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00       132
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00       203
#                             Diabetes       1.00      1.00      1.00       190
#                              Healthy       1.00      1.00      1.00       211
#                         Hypertension       1.00      1.00      1.00       153
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00       205
#             Stress-related Disorders       1.00      1.00      1.00       215
#
#                             accuracy                           1.00      2000
#                            macro avg       1.00      1.00      1.00      2000
#                         weighted avg       1.00      1.00      1.00      2000
#
# Accuracy: 1.0
#
#
# Batch Size: 15000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00      1547
#                          Arrhythmias       1.00      1.00      1.00      1604
#                      Atherosclerosis       1.00      1.00      1.00       561
#                Autonomic Dysfunction       1.00      1.00      1.00      1582
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00       859
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00      1519
#                             Diabetes       1.00      1.00      1.00      1551
#                              Healthy       1.00      1.00      1.00      1546
#                         Hypertension       1.00      1.00      1.00      1099
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00      1563
#             Stress-related Disorders       1.00      1.00      1.00      1569
#
#                             accuracy                           1.00     15000
#                            macro avg       1.00      1.00      1.00     15000
#                         weighted avg       1.00      1.00      1.00     15000
#
# Accuracy: 1.0

# %% [markdown]
# <h5 style="color: SkyBlue;">Gradient Boosting (GBM)</h5>

# %%
gradient_boosting_model = GradientBoostingClassifier(random_state=42)
train_and_evaluate(gradient_boosting_model, X_resampled, y_resampled, batch_sizes)
# Out:
# Batch Size: 200
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00        23
#                          Arrhythmias       1.00      1.00      1.00        18
#                      Atherosclerosis       1.00      1.00      1.00         4
#                Autonomic Dysfunction       1.00      1.00      1.00        14
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        14
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        20
#                             Diabetes       1.00      1.00      1.00        25
#                              Healthy       1.00      1.00      1.00        21
#                         Hypertension       1.00      1.00      1.00        18
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        21
#             Stress-related Disorders       1.00      1.00      1.00        22
#
#                             accuracy                           1.00       200
#                            macro avg       1.00      1.00      1.00       200
#                         weighted avg       1.00      1.00      1.00       200
#
# Accuracy: 1.0
#
#
# Batch Size: 400
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00        44
#                          Arrhythmias       1.00      1.00      1.00        35
#                      Atherosclerosis       1.00      1.00      1.00        12
#                Autonomic Dysfunction       1.00      1.00      1.00        41
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        22
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        38
#                             Diabetes       1.00      1.00      1.00        45
#                              Healthy       1.00      1.00      1.00        45
#                         Hypertension       1.00      1.00      1.00        32
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        39
#             Stress-related Disorders       1.00      1.00      1.00        47
#
#                             accuracy                           1.00       400
#                            macro avg       1.00      1.00      1.00       400
#                         weighted avg       1.00      1.00      1.00       400
#
# Accuracy: 1.0
#
#
# Batch Size: 800
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00        91
#                          Arrhythmias       1.00      1.00      1.00        82
#                      Atherosclerosis       1.00      1.00      1.00        29
#                Autonomic Dysfunction       1.00      1.00      1.00        74
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        53
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        78
#                             Diabetes       1.00      1.00      1.00        83
#                              Healthy       1.00      1.00      1.00        87
#                         Hypertension       1.00      1.00      1.00        58
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        76
#             Stress-related Disorders       1.00      1.00      1.00        89
#
#                             accuracy                           1.00       800
#                            macro avg       1.00      1.00      1.00       800
#                         weighted avg       1.00      1.00      1.00       800
#
# Accuracy: 1.0
#
#
# Batch Size: 1000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00       110
#                          Arrhythmias       1.00      1.00      1.00       101
#                      Atherosclerosis       1.00      1.00      1.00        35
#                Autonomic Dysfunction       1.00      1.00      1.00        95
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        71
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00       101
#                             Diabetes       1.00      1.00      1.00       106
#                              Healthy       1.00      1.00      1.00       105
#                         Hypertension       1.00      1.00      1.00        73
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        98
#             Stress-related Disorders       1.00      1.00      1.00       105
#
#                             accuracy                           1.00      1000
#                            macro avg       1.00      1.00      1.00      1000
#                         weighted avg       1.00      1.00      1.00      1000
#
# Accuracy: 1.0
#
#
# Batch Size: 2000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00       213
#                          Arrhythmias       1.00      1.00      1.00       205
#                      Atherosclerosis       1.00      1.00      1.00        67
#                Autonomic Dysfunction       1.00      1.00      1.00       206
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00       132
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00       203
#                             Diabetes       1.00      1.00      1.00       190
#                              Healthy       1.00      1.00      1.00       211
#                         Hypertension       1.00      1.00      1.00       153
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00       205
#             Stress-related Disorders       1.00      1.00      1.00       215
#
#                             accuracy                           1.00      2000
#                            macro avg       1.00      1.00      1.00      2000
#                         weighted avg       1.00      1.00      1.00      2000
#
# Accuracy: 1.0
#
#
# Batch Size: 15000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00      1547
#                          Arrhythmias       1.00      1.00      1.00      1604
#                      Atherosclerosis       1.00      1.00      1.00       561
#                Autonomic Dysfunction       1.00      1.00      1.00      1582
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00       859
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00      1519
#                             Diabetes       1.00      1.00      1.00      1551
#                              Healthy       1.00      1.00      1.00      1546
#                         Hypertension       1.00      1.00      1.00      1099
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00      1563
#             Stress-related Disorders       1.00      1.00      1.00      1569
#
#                             accuracy                           1.00     15000
#                            macro avg       1.00      1.00      1.00     15000
#                         weighted avg       1.00      1.00      1.00     15000
#
# Accuracy: 1.0

# %% [markdown]
# <h5 style="color: SkyBlue;">K-Nearest Neighbors (KNN)</h5>

# %%
knn_model = KNeighborsClassifier()
train_and_evaluate(knn_model, X_resampled, y_resampled, batch_sizes)
# Out:
# Batch Size: 200
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.49      0.91      0.64        23
#                          Arrhythmias       0.44      0.94      0.60        18
#                      Atherosclerosis       1.00      0.50      0.67         4
#                Autonomic Dysfunction       0.53      0.64      0.58        14
#         Cardiovascular Disease (CVD)       0.00      0.00      0.00        14
#       Chronic Fatigue Syndrome (CFS)       0.79      0.55      0.65        20
#                             Diabetes       0.65      0.80      0.71        25
#                              Healthy       0.78      0.86      0.82        21
#                         Hypertension       1.00      0.39      0.56        18
# Respiratory Disease (COPD or Asthma)       0.88      0.33      0.48        21
#             Stress-related Disorders       0.73      0.50      0.59        22
#
#                             accuracy                           0.61       200
#                            macro avg       0.66      0.58      0.57       200
#                         weighted avg       0.66      0.61      0.59       200
#
# Accuracy: 0.615
#
#
# Batch Size: 400
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.73      0.93      0.82        44
#                          Arrhythmias       0.53      0.97      0.69        35
#                      Atherosclerosis       0.78      0.58      0.67        12
#                Autonomic Dysfunction       0.70      0.80      0.75        41
#         Cardiovascular Disease (CVD)       0.83      0.23      0.36        22
#       Chronic Fatigue Syndrome (CFS)       0.78      0.47      0.59        38
#                             Diabetes       0.61      0.93      0.74        45
#                              Healthy       0.72      0.93      0.82        45
#                         Hypertension       0.92      0.34      0.50        32
# Respiratory Disease (COPD or Asthma)       0.71      0.31      0.43        39
#             Stress-related Disorders       0.67      0.55      0.60        47
#
#                             accuracy                           0.68       400
#                            macro avg       0.73      0.64      0.63       400
#                         weighted avg       0.71      0.68      0.65       400
#
# Accuracy: 0.6775
#
#
# Batch Size: 800
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.82      0.97      0.89        91
#                          Arrhythmias       0.64      0.94      0.76        82
#                      Atherosclerosis       0.81      0.59      0.68        29
#                Autonomic Dysfunction       0.70      0.91      0.79        74
#         Cardiovascular Disease (CVD)       0.87      0.38      0.53        53
#       Chronic Fatigue Syndrome (CFS)       0.83      0.69      0.76        78
#                             Diabetes       0.71      0.93      0.81        83
#                              Healthy       0.82      0.97      0.88        87
#                         Hypertension       0.86      0.43      0.57        58
# Respiratory Disease (COPD or Asthma)       0.76      0.33      0.46        76
#             Stress-related Disorders       0.76      0.81      0.78        89
#
#                             accuracy                           0.76       800
#                            macro avg       0.78      0.72      0.72       800
#                         weighted avg       0.77      0.76      0.74       800
#
# Accuracy: 0.7575
#
#
# Batch Size: 1000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.83      0.96      0.89       110
#                          Arrhythmias       0.63      0.95      0.76       101
#                      Atherosclerosis       0.84      0.60      0.70        35
#                Autonomic Dysfunction       0.77      0.93      0.84        95
#         Cardiovascular Disease (CVD)       0.86      0.42      0.57        71
#       Chronic Fatigue Syndrome (CFS)       0.77      0.72      0.74       101
#                             Diabetes       0.75      0.93      0.83       106
#                              Healthy       0.80      0.98      0.88       105
#                         Hypertension       0.89      0.42      0.57        73
# Respiratory Disease (COPD or Asthma)       0.68      0.31      0.42        98
#             Stress-related Disorders       0.71      0.74      0.73       105
#
#                             accuracy                           0.76      1000
#                            macro avg       0.77      0.72      0.72      1000
#                         weighted avg       0.76      0.76      0.73      1000
#
# Accuracy: 0.755
#
#
# Batch Size: 2000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.91      0.99      0.95       213
#                          Arrhythmias       0.75      0.97      0.84       205
#                      Atherosclerosis       0.84      0.73      0.78        67
#                Autonomic Dysfunction       0.85      0.99      0.91       206
#         Cardiovascular Disease (CVD)       0.81      0.58      0.68       132
#       Chronic Fatigue Syndrome (CFS)       0.83      0.73      0.78       203
#                             Diabetes       0.80      0.98      0.88       190
#                              Healthy       0.89      0.99      0.94       211
#                         Hypertension       0.83      0.49      0.62       153
# Respiratory Disease (COPD or Asthma)       0.77      0.48      0.59       205
#             Stress-related Disorders       0.80      0.92      0.85       215
#
#                             accuracy                           0.83      2000
#                            macro avg       0.83      0.80      0.80      2000
#                         weighted avg       0.83      0.83      0.81      2000
#
# Accuracy: 0.826
#
#
# Batch Size: 15000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.98      1.00      0.99      1547
#                          Arrhythmias       0.88      1.00      0.94      1604
#                      Atherosclerosis       0.90      0.89      0.90       561
#                Autonomic Dysfunction       0.95      1.00      0.97      1582
#         Cardiovascular Disease (CVD)       0.93      0.79      0.86       859
#       Chronic Fatigue Syndrome (CFS)       0.90      0.89      0.90      1519
#                             Diabetes       0.96      1.00      0.98      1551
#                              Healthy       0.96      1.00      0.98      1546
#                         Hypertension       0.94      0.75      0.83      1099
# Respiratory Disease (COPD or Asthma)       0.86      0.70      0.77      1563
#             Stress-related Disorders       0.88      1.00      0.94      1569
#
#                             accuracy                           0.92     15000
#                            macro avg       0.92      0.91      0.91     15000
#                         weighted avg       0.92      0.92      0.92     15000
#
# Accuracy: 0.9234

# %% [markdown]
# <h5 style="color: SkyBlue;">XGBoost</h5>

# %%
# y_resampled_encoded to a Pandas Series
y_resampled_encoded = pd.Series(y_resampled_encoded, index=X_resampled.index)

xgb_model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
train_and_evaluate(xgb_model, X_resampled, y_resampled_encoded, batch_sizes)
# Out:
# c:\Users\zen\Documents\les trucs du boulot\TM R&D\E-Health\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:25:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Batch Size: 200
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        23
#            1       1.00      1.00      1.00        18
#            2       1.00      1.00      1.00         4
#            3       1.00      1.00      1.00        14
#            4       1.00      1.00      1.00        14
#            5       1.00      1.00      1.00        20
#            6       1.00      1.00      1.00        25
#            7       1.00      1.00      1.00        21
#            8       1.00      1.00      1.00        18
#            9       1.00      1.00      1.00        21
#           10       1.00      1.00      1.00        22
#
#     accuracy                           1.00       200
#    macro avg       1.00      1.00      1.00       200
# weighted avg       1.00      1.00      1.00       200
#
# Accuracy: 1.0
# c:\Users\zen\Documents\les trucs du boulot\TM R&D\E-Health\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:25:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Batch Size: 400
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        44
#            1       1.00      1.00      1.00        35
#            2       1.00      1.00      1.00        12
#            3       1.00      1.00      1.00        41
#            4       1.00      1.00      1.00        22
#            5       1.00      1.00      1.00        38
#            6       1.00      1.00      1.00        45
#            7       1.00      1.00      1.00        45
#            8       1.00      1.00      1.00        32
#            9       1.00      1.00      1.00        39
#           10       1.00      1.00      1.00        47
#
#     accuracy                           1.00       400
#    macro avg       1.00      1.00      1.00       400
# weighted avg       1.00      1.00      1.00       400
#
# Accuracy: 1.0
# c:\Users\zen\Documents\les trucs du boulot\TM R&D\E-Health\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:25:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Batch Size: 800
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        91
#            1       1.00      1.00      1.00        82
#            2       1.00      1.00      1.00        29
#            3       1.00      1.00      1.00        74
#            4       1.00      1.00      1.00        53
#            5       1.00      1.00      1.00        78
#            6       1.00      1.00      1.00        83
#            7       1.00      1.00      1.00        87
#            8       1.00      1.00      1.00        58
#            9       1.00      1.00      1.00        76
#           10       1.00      1.00      1.00        89
#
#     accuracy                           1.00       800
#    macro avg       1.00      1.00      1.00       800
# weighted avg       1.00      1.00      1.00       800
#
# Accuracy: 1.0
# c:\Users\zen\Documents\les trucs du boulot\TM R&D\E-Health\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:25:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Batch Size: 1000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       110
#            1       1.00      1.00      1.00       101
#            2       1.00      1.00      1.00        35
#            3       1.00      1.00      1.00        95
#            4       1.00      1.00      1.00        71
#            5       1.00      1.00      1.00       101
#            6       1.00      1.00      1.00       106
#            7       1.00      1.00      1.00       105
#            8       1.00      1.00      1.00        73
#            9       1.00      1.00      1.00        98
#           10       1.00      1.00      1.00       105
#
#     accuracy                           1.00      1000
#    macro avg       1.00      1.00      1.00      1000
# weighted avg       1.00      1.00      1.00      1000
#
# Accuracy: 1.0
# c:\Users\zen\Documents\les trucs du boulot\TM R&D\E-Health\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:25:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Batch Size: 2000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       213
#            1       1.00      1.00      1.00       205
#            2       1.00      1.00      1.00        67
#            3       1.00      1.00      1.00       206
#            4       1.00      1.00      1.00       132
#            5       1.00      1.00      1.00       203
#            6       1.00      1.00      1.00       190
#            7       1.00      1.00      1.00       211
#            8       1.00      1.00      1.00       153
#            9       1.00      1.00      1.00       205
#           10       1.00      1.00      1.00       215
#
#     accuracy                           1.00      2000
#    macro avg       1.00      1.00      1.00      2000
# weighted avg       1.00      1.00      1.00      2000
#
# Accuracy: 1.0
# c:\Users\zen\Documents\les trucs du boulot\TM R&D\E-Health\.venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [10:25:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0ed59c031377d09b8-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Batch Size: 15000
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1547
#            1       1.00      1.00      1.00      1604
#            2       1.00      1.00      1.00       561
#            3       1.00      1.00      1.00      1582
#            4       1.00      1.00      1.00       859
#            5       1.00      1.00      1.00      1519
#            6       1.00      1.00      1.00      1551
#            7       1.00      1.00      1.00      1546
#            8       1.00      1.00      1.00      1099
#            9       1.00      1.00      1.00      1563
#           10       1.00      1.00      1.00      1569
#
#     accuracy                           1.00     15000
#    macro avg       1.00      1.00      1.00     15000
# weighted avg       1.00      1.00      1.00     15000
#
# Accuracy: 1.0

# %% [markdown]
# <h5 style="color: SkyBlue;">Extra Trees Classifier</h5>

# %%
extra_trees_model = ExtraTreesClassifier(random_state=42)
train_and_evaluate(extra_trees_model, X_resampled, y_resampled, batch_sizes)
# Out:
# Batch Size: 200
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00        23
#                          Arrhythmias       1.00      1.00      1.00        18
#                      Atherosclerosis       1.00      1.00      1.00         4
#                Autonomic Dysfunction       1.00      1.00      1.00        14
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        14
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        20
#                             Diabetes       1.00      1.00      1.00        25
#                              Healthy       1.00      1.00      1.00        21
#                         Hypertension       1.00      1.00      1.00        18
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        21
#             Stress-related Disorders       1.00      1.00      1.00        22
#
#                             accuracy                           1.00       200
#                            macro avg       1.00      1.00      1.00       200
#                         weighted avg       1.00      1.00      1.00       200
#
# Accuracy: 1.0
#
#
# Batch Size: 400
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00        44
#                          Arrhythmias       1.00      1.00      1.00        35
#                      Atherosclerosis       1.00      1.00      1.00        12
#                Autonomic Dysfunction       1.00      1.00      1.00        41
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        22
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        38
#                             Diabetes       1.00      1.00      1.00        45
#                              Healthy       1.00      1.00      1.00        45
#                         Hypertension       1.00      1.00      1.00        32
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        39
#             Stress-related Disorders       1.00      1.00      1.00        47
#
#                             accuracy                           1.00       400
#                            macro avg       1.00      1.00      1.00       400
#                         weighted avg       1.00      1.00      1.00       400
#
# Accuracy: 1.0
#
#
# Batch Size: 800
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00        91
#                          Arrhythmias       1.00      1.00      1.00        82
#                      Atherosclerosis       1.00      1.00      1.00        29
#                Autonomic Dysfunction       1.00      1.00      1.00        74
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        53
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        78
#                             Diabetes       1.00      1.00      1.00        83
#                              Healthy       1.00      1.00      1.00        87
#                         Hypertension       1.00      1.00      1.00        58
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        76
#             Stress-related Disorders       1.00      1.00      1.00        89
#
#                             accuracy                           1.00       800
#                            macro avg       1.00      1.00      1.00       800
#                         weighted avg       1.00      1.00      1.00       800
#
# Accuracy: 1.0
#
#
# Batch Size: 1000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00       110
#                          Arrhythmias       1.00      1.00      1.00       101
#                      Atherosclerosis       1.00      1.00      1.00        35
#                Autonomic Dysfunction       1.00      1.00      1.00        95
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00        71
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00       101
#                             Diabetes       1.00      1.00      1.00       106
#                              Healthy       1.00      1.00      1.00       105
#                         Hypertension       1.00      1.00      1.00        73
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00        98
#             Stress-related Disorders       1.00      1.00      1.00       105
#
#                             accuracy                           1.00      1000
#                            macro avg       1.00      1.00      1.00      1000
#                         weighted avg       1.00      1.00      1.00      1000
#
# Accuracy: 1.0
#
#
# Batch Size: 2000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00       213
#                          Arrhythmias       1.00      1.00      1.00       205
#                      Atherosclerosis       1.00      1.00      1.00        67
#                Autonomic Dysfunction       1.00      1.00      1.00       206
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00       132
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00       203
#                             Diabetes       1.00      1.00      1.00       190
#                              Healthy       1.00      1.00      1.00       211
#                         Hypertension       1.00      1.00      1.00       153
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00       205
#             Stress-related Disorders       1.00      1.00      1.00       215
#
#                             accuracy                           1.00      2000
#                            macro avg       1.00      1.00      1.00      2000
#                         weighted avg       1.00      1.00      1.00      2000
#
# Accuracy: 1.0
#
#
# Batch Size: 15000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      1.00      1.00      1547
#                          Arrhythmias       1.00      1.00      1.00      1604
#                      Atherosclerosis       1.00      1.00      1.00       561
#                Autonomic Dysfunction       1.00      1.00      1.00      1582
#         Cardiovascular Disease (CVD)       1.00      1.00      1.00       859
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00      1519
#                             Diabetes       1.00      1.00      1.00      1551
#                              Healthy       1.00      1.00      1.00      1546
#                         Hypertension       1.00      1.00      1.00      1099
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00      1563
#             Stress-related Disorders       1.00      1.00      1.00      1569
#
#                             accuracy                           1.00     15000
#                            macro avg       1.00      1.00      1.00     15000
#                         weighted avg       1.00      1.00      1.00     15000
#
# Accuracy: 1.0
